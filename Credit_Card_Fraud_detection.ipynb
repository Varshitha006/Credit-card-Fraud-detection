# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/content/creditcard.csv')

# %%
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (27819, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27819 entries, 0 to 27818
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    27819 non-null  int64
#  1   V1      27818 non-null  float64
#  2   V2      27818 non-null  float64
#  3   V3      27818 non-null  float64
#  4   V4      27818 non-null  float64
#  5   V5      27818 non-null  float64
#  6   V6      27818 non-null  float64
#  7   V7      27818 non-null  float64
#  8   V8      27818 non-null  float64
#  9   V9      27818 non-null  float64
#  10  V10     27818 non-null  float64
#  11  V11     27818 non-null  float64
#  12  V12     27818 non-null  float64
#  13  V13     27818 non-null  float64
#  14  V14     27818 non-null  float64
#  15  V15     27818 non-null  float64
#  16  V16     27818 non-null  float64
#  17  V17     27818 non-null  float64
#  18  V18     27818 non-null  float64
#  19  V19     27818 non-null  float64
#  20  V20     27818 non-null  float64
#  21  V21     27818 non-null  float64
#  22  V22     27818 non-null  float64
#  23  V23     27818 non-null  float64
#  24  V24     27818 non-null  float64
#  25  V25     27818 non-null  float64
#  26  V26     27818 non-null  float64
#  27  V27     27818 non-null  float64
#  28  V28     27818 non-null  float64
#  29  Amount  27818 non-null  float64
#  30  Class   27818 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 6.6 MB

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        1
# V2        1
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28    Amount  Class
# 0 -0.189115  0.133558 -0.021053  0.329267    0.0
# 1  0.125895 -0.008983  0.014724 -0.339668    0.0
# 2 -0.139097 -0.055353 -0.059752  1.372029    0.0
# 3 -0.221929  0.062723  0.061458  0.210349    0.0
# 4  0.502292  0.219422  0.215153 -0.033268    0.0
#
# [5 rows x 31 columns]

# %%
data=data.drop(['Time'],axis=1)

# %%
data.shape
# Out:
# (27819, 30)

# %%
data.duplicated().any()
# Out:
# True

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (27111, 30)

# %%
data['Class'].value_counts()
# Out:
# Class
# 0.0    27017
# 1.0       93
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(data['Class'])
# Out:
# <Axes: ylabel='count'>

# %%
X = data.drop('Class',axis=1)
y = data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
normal = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
normal.shape
# Out:
# (27017, 30)

# %%
fraud.shape
# Out:
# (93, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_data = pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0.0    473
# 1.0     93
# Name: count, dtype: int64

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  1.297209  0.750957 -0.682946  1.147814  0.552670 -0.748080  0.339017
# 1  1.121093  0.111322  0.498386  1.328600 -0.272976  0.001349 -0.110423
# 2  1.189598  0.289716  0.516757  0.942567 -0.435072 -0.785810 -0.200526
# 3  1.047051  0.055205  1.598788  2.944703 -0.837250  0.660946 -0.711426
# 4  1.146619 -0.466438  0.948458  0.065914 -0.877668  0.447087 -0.932231
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0 -0.229265 -0.133449 -0.699750  ... -0.115328 -0.222498 -0.235285 -0.570828
# 1  0.179641  0.174675  0.077668  ... -0.053130  0.012710 -0.030376  0.216249
# 2 -0.062029  1.570873 -0.644168  ... -0.409582 -0.993680  0.231981  0.248527
# 3  0.349164  0.506210  0.353771  ...  0.064240  0.557378 -0.052925  0.442928
# 4  0.396400  0.891311 -0.134078  ...  0.125968  0.457356 -0.051646 -0.245949
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.825514 -0.277546  0.038467  0.050407 -0.347362    0.0
# 1  0.573753 -0.338610  0.030965  0.004415 -0.347362    0.0
# 2  0.013788  0.071387 -0.045194  0.020543 -0.338302    0.0
# 3  0.484869  0.224058  0.062520  0.025824 -0.351915    0.0
# 4  0.156889  0.945173 -0.016843 -0.000678 -0.296372    0.0
#
# [5 rows x 30 columns]

# %%
X = new_data.drop('Class',axis=1)
y = new_data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9824561403508771

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred)
# Out:
# 1.0

# %%
recall_score(y_test,y_pred)
# Out:
# 0.8888888888888888
